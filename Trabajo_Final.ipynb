# %%
import pandas as pd
import pymysql
import matplotlib.pyplot as plt 
# %matplotlib inline
import seaborn as sns
# %load_ext sql

# %%
# %sql mysql+pymysql://root:x1x2x3x4x5@localhost:3306/IBM

# %%
# %sql select count(*) from Chicago_Crime_Data  #nùmero de crimenes de Chicago
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 1 rows affected.
# [(353,)]

# %%
# %sql select * from Chicago_Crime_Data limit 10  #Primeras 10 lineas de la tabla Crime
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 10 rows affected.
# [(3512276, 'HK587712', '08/28/2004 05:50:56 PM', '047XX S KEDZIE AVE', 890, 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, 6, 1155838, 1873050, 2004, '02/10/2018 03:50:01 PM', 41.8074405, -87.70395585, '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '06/26/2004 12:40:00 PM', '009XX N CENTRAL PARK AVE', 820, 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, 6, 1152206, 1906127, 2004, '02/28/2018 03:56:25 PM', 41.89827996, -87.71640551, '(41.898279962, -87.716405505)'),
#  (8002131, 'HT233595', '04/04/2011 05:45:00 AM', '043XX S WABASH AVE', 820, 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 'FALSE', 'FALSE', 221, 2, 3, 38, 6, 1177436, 1876313, 2011, '02/10/2018 03:50:01 PM', 41.81593313, -87.62464213, '(41.815933131, -87.624642127)'),
# ...

# %%
# %sql select count(ARREST) from Chicago_Crime_Data where ARREST like "TRUE" #Numero de casos que terminaron en arresto##
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 1 rows affected.
# [(108,)]

# %%
# %sql select primary_type,location_description from Chicago_Crime_Data where location_description like "%GAS%" 
### Tipos de delito por location
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 5 rows affected.
# [('THEFT', 'GAS STATION'),
#  ('THEFT', 'GAS STATION'),
#  ('NARCOTICS', 'GAS STATION'),
#  ('ROBBERY', 'GAS STATION'),
#  ('CRIMINAL TRESPASS', 'GAS STATION')]

# %%
# %sql select * from Census_Data limit 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 5 rows affected.
# [(1, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39),
#  (2, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46),
#  (3, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20),
#  (4, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17),
#  (5, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6)]

# %%
# %sql select community_area_name from Census_Data where community_area_name like "B%"
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 5 rows affected.
# [('Belmont Cragin',),
#  ('Burnside',),
#  ('Brighton Park',),
#  ('Bridgeport',),
#  ('Beverly',)]

# %%
# %sql select * from CPS limit 5
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 5 rows affected.
# [(610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl ', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99, 'Very Strong', '99', 'Strong', 74, 'Strong', 66, 'Strong', '65', 'Strong', '70', 'Strong', 56, 'Average', 47, '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', '69.7', '64.4', '0.2', '0.9', 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %%
# %sql select community_area_number,HEALTHY_SCHOOL_CERTIFIED from CPS where community_area_number between 10 and 15
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 24 rows affected.
# [(14, 'No'),
#  (14, 'No'),
#  (12, 'No'),
#  (10, 'No'),
#  (15, 'No'),
#  (13, 'No'),
#  (14, 'No'),
#  (15, 'No'),
#  (11, 'No'),
#  (14, 'No'),
#  (10, 'No'),
#  (13, 'No'),
#  (14, 'No'),
#  (13, 'No'),
#  (13, 'No'),
#  (10, 'No'),
#  (10, 'No'),
#  (15, 'No'),
#  (15, 'No'),
#  (10, 'Yes'),
#  (14, 'No'),
#  (12, 'No'),
#  (10, 'No'),
#  (15, 'No')]

# %%
# %sql select avg(safety_score) from CPS where community_area_number between 10 and 15
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 1 rows affected.
# [(Decimal('73.5000'),)]

# %%
# %sql select community_area_number,sum(COLLEGE_ENROLLMENT) as total_enroll from CPS group by community_area_number\
order by total_enroll DESC
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 73 rows affected.
# [(30, Decimal('9232')),
#  (19, Decimal('8456')),
#  (25, Decimal('8198')),
#  (61, Decimal('7922')),
#  (70, Decimal('6483')),
#  (22, Decimal('6392')),
#  (6, Decimal('6326')),
#  (58, Decimal('6073')),
#  (28, Decimal('5920')),
#  (23, Decimal('5423')),
#  (24, Decimal('5413')),
#  (63, Decimal('5407')),
#  (67, Decimal('5391')),
#  (66, Decimal('4705')),
#  (16, Decimal('4600')),
#  (15, Decimal('4191')),
#  (14, Decimal('4135')),
#  (4, Decimal('4132')),
#  (68, Decimal('4106')),
#  (17, Decimal('4066')),
#  (31, Decimal('4009')),
#  (2, Decimal('3892')),
#  (49, Decimal('3872')),
#  (52, Decimal('3781')),
#  (21, Decimal('3640')),
#  (71, Decimal('3391')),
#  (10, Decimal('3387')),
#  (27, Decimal('3050')),
#  (56, Decimal('2963')),
#  (46, Decimal('2893')),
#  (73, Decimal('2780')),
#  (29, Decimal('2767')),
#  (43, Decimal('2654')),
#  (69, Decimal('2594')),
#  (13, Decimal('2574')),
# ...

# %%
# %sql select community_area_number,safety_score from CPS where safety_score=(select min(safety_score) from CPS) 

## Hacer busquedad anidada
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 1 rows affected.
# [(40, 1)]

# %%
ingreso_seguridad = %sql select census.per_capita_income, cps.safety_score from Census_Data as census, CPS as cps\
where census.community_area_number=cps.community_area_number\
#order by safety_score ASC limit 50

# Relaciona dos tablas a partir de una columna en comun
# Out:
#  * mysql+pymysql://root:***@localhost:3306/IBM
# 391 rows affected.

# %%
plot = sns.jointplot(x='per_capita_income',y='safety_score', data=ingreso_seguridad.DataFrame())
